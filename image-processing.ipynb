# %%
import matplotlib.pyplot as plt
import numpy  as np
import pandas as pd
import sklearn

# %%
from astropy.io import fits
from sklearn import datasets
sklearn.datasets
# Out:
# <module 'sklearn.datasets' from 'C:\\Users\\ashwa\\anaconda3\\lib\\site-packages\\sklearn\\datasets\\__init__.py'>

# %%
ngcu = fits.open("frame-u-006122-1-0013.fits")

# %%
ngcu
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x000001F027F281C0>, <astropy.io.fits.hdu.image.ImageHDU object at 0x000001F021E4D6A0>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x000001F0282C8AF0>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x000001F0282C8A00>]

# %%
ngcu.info()
# Out:
# Filename: frame-u-006122-1-0013.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      96   (2048, 1489)   float32
#   1                1 ImageHDU         6   (2048,)   float32
#   2                1 BinTableHDU     27   1R x 3C   [49152E, 2048E, 1489E]
#   3                1 BinTableHDU     79   1R x 31C   [J, 3A, J, A, D, D, 2J, J, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, E, E]

# %%
from astropy.visualization import make_lupton_rgb

# %%
ngci=fits.open('frame-i-006122-1-0013.fits.bz2')

# %%
ngci.info()
# Out:
# Filename: frame-i-006122-1-0013.fits.bz2
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      96   (2048, 1489)   float32
#   1                1 ImageHDU         6   (2048,)   float32
#   2                1 BinTableHDU     27   1R x 3C   [49152E, 2048E, 1489E]
#   3                1 BinTableHDU     79   1R x 31C   [J, 3A, J, A, D, D, 2J, J, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, E, E]

# %%
ngcg = fits.open('frame-g-006122-1-0013.fits.bz2')

# %%
ngcg.info()
# Out:
# Filename: frame-g-006122-1-0013.fits.bz2
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      96   (2048, 1489)   float32
#   1                1 ImageHDU         6   (2048,)   float32
#   2                1 BinTableHDU     27   1R x 3C   [49152E, 2048E, 1489E]
#   3                1 BinTableHDU     79   1R x 31C   [J, 3A, J, A, D, D, 2J, J, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, E, E]

# %%
g=ngcg[0].data
i=ngci[0].data
u=ngcu[0].data

# %%
rgb_default=make_lupton_rgb(g, i, u, stretch=0.5,Q=10)

plt.imshow(rgb_default, origin='lower')
plt.savefig('rgbngc.jpg')

# %%
ngcg[0].data
# Out:
# array([[ 0.01512146,  0.01861572,  0.02911377, ..., -0.04077148,
#          0.01483154, -0.01295471],
#        [-0.01635742,  0.01512146,  0.00811768, ...,  0.00441742,
#         -0.00252914,  0.00441742],
#        [ 0.00112343, -0.00587463,  0.02560425, ..., -0.04077148,
#          0.03222656,  0.02526855],
#        ...,
#        [-0.00509644, -0.00509644,  0.00889587, ...,  0.01216125,
#          0.015625  , -0.02606201],
#        [ 0.00190353, -0.00159454,  0.01937866, ..., -0.00521088,
#         -0.00173759, -0.00521088],
#        [ 0.00540161, -0.00159454,  0.00190353, ..., -0.03649902,
#          0.015625  ,  0.015625  ]], dtype=float32)
